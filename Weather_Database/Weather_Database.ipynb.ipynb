# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 729

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather["weather"][0]["description"]  
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao joao da barra
# Processing Record 2 of Set 1 | yulara
# Processing Record 3 of Set 1 | port hardy
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | shimoda
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | sal rei
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | salalah
# Processing Record 11 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | murray bridge
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | donji komren
# City not found. Skipping...
# Processing Record 20 of Set 1 | mizan teferi
# Processing Record 21 of Set 1 | mandalgovi
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | entre rios
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | puerto carreno
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | staro nagoricane
# City not found. Skipping...
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | kahului
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | yarada
# Processing Record 39 of Set 1 | sabinas hidalgo
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | libreville
# Processing Record 43 of Set 1 | wang saphung
# Processing Record 44 of Set 1 | quatre cocos
# Processing Record 45 of Set 1 | alyangula
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | kavieng
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 2 | sibolga
# Processing Record 4 of Set 2 | kununurra
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | moramanga
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | dudinka
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | koungou
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | grindavik
# Processing Record 17 of Set 2 | prince rupert
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | tynda
# Processing Record 20 of Set 2 | amalapuram
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | bathsheba
# Processing Record 23 of Set 2 | pizhma
# Processing Record 24 of Set 2 | tingrela
# City not found. Skipping...
# Processing Record 25 of Set 2 | old road
# City not found. Skipping...
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | labuhan
# Processing Record 28 of Set 2 | hualmay
# Processing Record 29 of Set 2 | sidney
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | kabompo
# Processing Record 34 of Set 2 | roald
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | robertsport
# Processing Record 38 of Set 2 | wenling
# Processing Record 39 of Set 2 | springbok
# Processing Record 40 of Set 2 | uhlove
# Processing Record 41 of Set 2 | margate
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | bocaranga
# City not found. Skipping...
# Processing Record 47 of Set 2 | sitka
# Processing Record 48 of Set 2 | atambua
# Processing Record 49 of Set 2 | dingle
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | nchelenge
# Processing Record 3 of Set 3 | purpe
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | talnakh
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | belaya gora
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | berlevag
# Processing Record 11 of Set 3 | camapua
# Processing Record 12 of Set 3 | sept-iles
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | cape town
# Processing Record 15 of Set 3 | ilheus
# Processing Record 16 of Set 3 | elat
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | santos dumont
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | fairbanks
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | ninghai
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | port-gentil
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | kalmunai
# Processing Record 29 of Set 3 | sao francisco
# Processing Record 30 of Set 3 | si sa ket
# Processing Record 31 of Set 3 | puerto leguizamo
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | vanimo
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | north bend
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | mayumba
# Processing Record 40 of Set 3 | port shepstone
# Processing Record 41 of Set 3 | leshukonskoye
# Processing Record 42 of Set 3 | nemuro
# Processing Record 43 of Set 3 | lodja
# Processing Record 44 of Set 3 | winnemucca
# Processing Record 45 of Set 3 | yegros
# Processing Record 46 of Set 3 | shihezi
# Processing Record 47 of Set 3 | camana
# Processing Record 48 of Set 3 | gazimurskiy zavod
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | odienne
# Processing Record 1 of Set 4 | villa carlos paz
# Processing Record 2 of Set 4 | jacksonville
# Processing Record 3 of Set 4 | manzhouli
# Processing Record 4 of Set 4 | atuona
# Processing Record 5 of Set 4 | san cristobal
# Processing Record 6 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 4 | barrow
# Processing Record 8 of Set 4 | meulaboh
# Processing Record 9 of Set 4 | tamworth
# Processing Record 10 of Set 4 | dalbandin
# Processing Record 11 of Set 4 | harbour breton
# Processing Record 12 of Set 4 | zhuhai
# Processing Record 13 of Set 4 | aksu
# Processing Record 14 of Set 4 | parabel
# Processing Record 15 of Set 4 | takoradi
# Processing Record 16 of Set 4 | eureka
# Processing Record 17 of Set 4 | skoghall
# Processing Record 18 of Set 4 | guerrero negro
# Processing Record 19 of Set 4 | datong
# Processing Record 20 of Set 4 | dalian
# Processing Record 21 of Set 4 | innisfail
# Processing Record 22 of Set 4 | erenhot
# Processing Record 23 of Set 4 | gold coast
# Processing Record 24 of Set 4 | whitianga
# Processing Record 25 of Set 4 | vila franca do campo
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | oga
# Processing Record 28 of Set 4 | boone
# Processing Record 29 of Set 4 | mildura
# Processing Record 30 of Set 4 | oranjestad
# Processing Record 31 of Set 4 | richards bay
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | bulgan
# Processing Record 34 of Set 4 | haines junction
# Processing Record 35 of Set 4 | kaz
# Processing Record 36 of Set 4 | payson
# Processing Record 37 of Set 4 | lagoa
# Processing Record 38 of Set 4 | lavrentiya
# Processing Record 39 of Set 4 | malartic
# Processing Record 40 of Set 4 | hami
# Processing Record 41 of Set 4 | talara
# Processing Record 42 of Set 4 | marawi
# Processing Record 43 of Set 4 | yima
# Processing Record 44 of Set 4 | sistranda
# Processing Record 45 of Set 4 | sobolevo
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | chokurdakh
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | la ronge
# Processing Record 1 of Set 5 | conceicao do araguaia
# Processing Record 2 of Set 5 | villiers
# Processing Record 3 of Set 5 | muros
# Processing Record 4 of Set 5 | rio verde de mato grosso
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | natal
# Processing Record 7 of Set 5 | luena
# Processing Record 8 of Set 5 | kekri
# Processing Record 9 of Set 5 | mathathane
# Processing Record 10 of Set 5 | namibe
# Processing Record 11 of Set 5 | biak
# Processing Record 12 of Set 5 | kobojango
# City not found. Skipping...
# Processing Record 13 of Set 5 | tabou
# Processing Record 14 of Set 5 | kalabo
# Processing Record 15 of Set 5 | bonthe
# Processing Record 16 of Set 5 | magadan
# Processing Record 17 of Set 5 | laguna
# Processing Record 18 of Set 5 | gamboma
# Processing Record 19 of Set 5 | bay roberts
# Processing Record 20 of Set 5 | uyuni
# Processing Record 21 of Set 5 | muravlenko
# Processing Record 22 of Set 5 | olafsvik
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | kasane
# Processing Record 25 of Set 5 | teodoro sampaio
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | srednekolymsk
# Processing Record 28 of Set 5 | derzhavinsk
# Processing Record 29 of Set 5 | zhanakorgan
# Processing Record 30 of Set 5 | quang ngai
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 33 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 5 | umm kaddadah
# Processing Record 35 of Set 5 | kurilsk
# Processing Record 36 of Set 5 | hirara
# Processing Record 37 of Set 5 | sorong
# Processing Record 38 of Set 5 | port lincoln
# Processing Record 39 of Set 5 | fujieda
# Processing Record 40 of Set 5 | hay river
# Processing Record 41 of Set 5 | banjar
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | nedjo
# Processing Record 44 of Set 5 | bilibino
# Processing Record 45 of Set 5 | college
# Processing Record 46 of Set 5 | castro
# Processing Record 47 of Set 5 | walvis bay
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | chapais
# Processing Record 50 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 6 | rosarito
# Processing Record 2 of Set 6 | huilong
# Processing Record 3 of Set 6 | nouadhibou
# Processing Record 4 of Set 6 | katubao
# Processing Record 5 of Set 6 | adre
# Processing Record 6 of Set 6 | gat
# Processing Record 7 of Set 6 | mudyuga
# City not found. Skipping...
# Processing Record 8 of Set 6 | tignere
# Processing Record 9 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 6 | kamaishi
# Processing Record 12 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 6 | burica
# City not found. Skipping...
# Processing Record 14 of Set 6 | saskylakh
# Processing Record 15 of Set 6 | atlantic beach
# Processing Record 16 of Set 6 | acapulco
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | samarai
# Processing Record 19 of Set 6 | katsuura
# Processing Record 20 of Set 6 | armidale
# Processing Record 21 of Set 6 | araxa
# Processing Record 22 of Set 6 | puntarenas
# Processing Record 23 of Set 6 | coquimbo
# Processing Record 24 of Set 6 | bam
# Processing Record 25 of Set 6 | khilok
# Processing Record 26 of Set 6 | itarema
# Processing Record 27 of Set 6 | bokoro
# Processing Record 28 of Set 6 | siguiri
# Processing Record 29 of Set 6 | cabo san lucas
# Processing Record 30 of Set 6 | upata
# Processing Record 31 of Set 6 | mazara del vallo
# Processing Record 32 of Set 6 | beringovskiy
# Processing Record 33 of Set 6 | bording
# Processing Record 34 of Set 6 | lasa
# Processing Record 35 of Set 6 | codrington
# Processing Record 36 of Set 6 | mayskiy
# Processing Record 37 of Set 6 | ribeira grande
# Processing Record 38 of Set 6 | bethel
# Processing Record 39 of Set 6 | corowa
# Processing Record 40 of Set 6 | kiunga
# Processing Record 41 of Set 6 | aberdeen
# Processing Record 42 of Set 6 | plettenberg bay
# Processing Record 43 of Set 6 | burgeo
# Processing Record 44 of Set 6 | yei
# Processing Record 45 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 6 | malim
# Processing Record 47 of Set 6 | tazovskiy
# Processing Record 48 of Set 6 | mar del plata
# Processing Record 49 of Set 6 | westport
# Processing Record 50 of Set 6 | kimberley
# Processing Record 1 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | port hedland
# Processing Record 4 of Set 7 | aguimes
# Processing Record 5 of Set 7 | east london
# Processing Record 6 of Set 7 | tanete
# Processing Record 7 of Set 7 | maldonado
# Processing Record 8 of Set 7 | pacific grove
# Processing Record 9 of Set 7 | ofaqim
# Processing Record 10 of Set 7 | mana
# Processing Record 11 of Set 7 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | henties bay
# Processing Record 13 of Set 7 | jining
# Processing Record 14 of Set 7 | makakilo city
# Processing Record 15 of Set 7 | canyon
# Processing Record 16 of Set 7 | erzin
# Processing Record 17 of Set 7 | alice town
# Processing Record 18 of Set 7 | calabar
# Processing Record 19 of Set 7 | esperance
# Processing Record 20 of Set 7 | sioux lookout
# Processing Record 21 of Set 7 | neiafu
# Processing Record 22 of Set 7 | whitehorse
# Processing Record 23 of Set 7 | upernavik
# Processing Record 24 of Set 7 | nuuk
# Processing Record 25 of Set 7 | gushikawa
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | tahoua
# Processing Record 28 of Set 7 | beyneu
# Processing Record 29 of Set 7 | ihosy
# Processing Record 30 of Set 7 | bol
# Processing Record 31 of Set 7 | auki
# Processing Record 32 of Set 7 | kalininsk
# Processing Record 33 of Set 7 | encheng
# Processing Record 34 of Set 7 | beterou
# Processing Record 35 of Set 7 | birao
# Processing Record 36 of Set 7 | olinda
# Processing Record 37 of Set 7 | navalgund
# Processing Record 38 of Set 7 | sovetskiy
# Processing Record 39 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 7 | tautira
# Processing Record 41 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 42 of Set 7 | san jeronimo
# Processing Record 43 of Set 7 | luganville
# Processing Record 44 of Set 7 | villazon
# Processing Record 45 of Set 7 | rio claro
# Processing Record 46 of Set 7 | shillong
# Processing Record 47 of Set 7 | cap malheureux
# Processing Record 48 of Set 7 | tungor
# Processing Record 49 of Set 7 | uenohara
# Processing Record 50 of Set 7 | shenyang
# Processing Record 1 of Set 8 | reconquista
# Processing Record 2 of Set 8 | kavaratti
# Processing Record 3 of Set 8 | tuscaloosa
# Processing Record 4 of Set 8 | eyl
# Processing Record 5 of Set 8 | mian channun
# Processing Record 6 of Set 8 | hofn
# Processing Record 7 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 8 | victoria
# Processing Record 9 of Set 8 | jilib
# Processing Record 10 of Set 8 | vanavara
# Processing Record 11 of Set 8 | tual
# Processing Record 12 of Set 8 | vagur
# Processing Record 13 of Set 8 | high prairie
# Processing Record 14 of Set 8 | steinbach
# Processing Record 15 of Set 8 | burnie
# Processing Record 16 of Set 8 | zapolyarnyy
# Processing Record 17 of Set 8 | mancora
# Processing Record 18 of Set 8 | arroyo
# Processing Record 19 of Set 8 | taian
# Processing Record 20 of Set 8 | beira
# Processing Record 21 of Set 8 | chilca
# Processing Record 22 of Set 8 | rodrigues alves
# Processing Record 23 of Set 8 | payo
# Processing Record 24 of Set 8 | chester
# Processing Record 25 of Set 8 | lata
# Processing Record 26 of Set 8 | karratha
# Processing Record 27 of Set 8 | yadgir
# Processing Record 28 of Set 8 | ossora
# Processing Record 29 of Set 8 | adrar
# Processing Record 30 of Set 8 | cururupu
# Processing Record 31 of Set 8 | kloulklubed
# Processing Record 32 of Set 8 | salinopolis
# Processing Record 33 of Set 8 | yaan
# Processing Record 34 of Set 8 | otkaznoye
# Processing Record 35 of Set 8 | malpura
# Processing Record 36 of Set 8 | cockburn town
# Processing Record 37 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 8 | saint-augustin
# Processing Record 39 of Set 8 | filimonovo
# Processing Record 40 of Set 8 | troitskoye
# Processing Record 41 of Set 8 | quelimane
# Processing Record 42 of Set 8 | paamiut
# Processing Record 43 of Set 8 | geraldton
# Processing Record 44 of Set 8 | coos bay
# Processing Record 45 of Set 8 | san quintin
# Processing Record 46 of Set 8 | chimbote
# Processing Record 47 of Set 8 | revda
# Processing Record 48 of Set 8 | akyab
# Processing Record 49 of Set 8 | sisimiut
# Processing Record 50 of Set 8 | ancud
# Processing Record 1 of Set 9 | shar
# Processing Record 2 of Set 9 | san patricio
# Processing Record 3 of Set 9 | dedougou
# Processing Record 4 of Set 9 | urumqi
# Processing Record 5 of Set 9 | yelizovo
# Processing Record 6 of Set 9 | bindura
# Processing Record 7 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | kupang
# Processing Record 10 of Set 9 | bykovo
# Processing Record 11 of Set 9 | necochea
# Processing Record 12 of Set 9 | mount isa
# Processing Record 13 of Set 9 | bontang
# Processing Record 14 of Set 9 | doka
# Processing Record 15 of Set 9 | merauke
# Processing Record 16 of Set 9 | jalu
# Processing Record 17 of Set 9 | sayyan
# Processing Record 18 of Set 9 | rudnya
# Processing Record 19 of Set 9 | tuatapere
# Processing Record 20 of Set 9 | acari
# Processing Record 21 of Set 9 | san miguel
# Processing Record 22 of Set 9 | newport
# Processing Record 23 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 24 of Set 9 | buritis
# Processing Record 25 of Set 9 | avera
# Processing Record 26 of Set 9 | inuvik
# Processing Record 27 of Set 9 | batagay-alyta
# Processing Record 28 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 9 | brae
# Processing Record 30 of Set 9 | nortelandia
# Processing Record 31 of Set 9 | great yarmouth
# Processing Record 32 of Set 9 | te anau
# Processing Record 33 of Set 9 | zabol
# Processing Record 34 of Set 9 | clyde river
# Processing Record 35 of Set 9 | tselina
# Processing Record 36 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 37 of Set 9 | preobrazheniye
# Processing Record 38 of Set 9 | abu samrah
# Processing Record 39 of Set 9 | tirumullaivasal
# Processing Record 40 of Set 9 | pedasi
# Processing Record 41 of Set 9 | lufilufi
# Processing Record 42 of Set 9 | burns lake
# Processing Record 43 of Set 9 | chake chake
# Processing Record 44 of Set 9 | riviere-au-renard
# Processing Record 45 of Set 9 | klyuchi
# Processing Record 46 of Set 9 | vallenar
# Processing Record 47 of Set 9 | lucapa
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 9 | dongsheng
# Processing Record 1 of Set 10 | breyten
# Processing Record 2 of Set 10 | hit
# Processing Record 3 of Set 10 | moncton
# Processing Record 4 of Set 10 | culipapa
# City not found. Skipping...
# Processing Record 5 of Set 10 | namatanai
# Processing Record 6 of Set 10 | tambura
# Processing Record 7 of Set 10 | takhtamygda
# Processing Record 8 of Set 10 | that phanom
# Processing Record 9 of Set 10 | along
# Processing Record 10 of Set 10 | todos santos
# Processing Record 11 of Set 10 | rawson
# Processing Record 12 of Set 10 | saquarema
# Processing Record 13 of Set 10 | tukrah
# Processing Record 14 of Set 10 | valparaiso
# Processing Record 15 of Set 10 | hammerfest
# Processing Record 16 of Set 10 | bacolod
# Processing Record 17 of Set 10 | senno
# Processing Record 18 of Set 10 | constitucion
# Processing Record 19 of Set 10 | rabo de peixe
# Processing Record 20 of Set 10 | lazaro cardenas
# Processing Record 21 of Set 10 | palu
# Processing Record 22 of Set 10 | pedra branca
# Processing Record 23 of Set 10 | singaraja
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | balaipungut
# Processing Record 26 of Set 10 | kovernino
# Processing Record 27 of Set 10 | alta floresta
# Processing Record 28 of Set 10 | linxia
# Processing Record 29 of Set 10 | fez
# Processing Record 30 of Set 10 | roswell
# Processing Record 31 of Set 10 | fredericton
# Processing Record 32 of Set 10 | mirnyy
# Processing Record 33 of Set 10 | takapau
# Processing Record 34 of Set 10 | rocha
# Processing Record 35 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 10 | nizwa
# Processing Record 37 of Set 10 | oistins
# Processing Record 38 of Set 10 | mogadishu
# Processing Record 39 of Set 10 | agropoli
# Processing Record 40 of Set 10 | irricana
# Processing Record 41 of Set 10 | phan thiet
# Processing Record 42 of Set 10 | kimbe
# Processing Record 43 of Set 10 | myitkyina
# Processing Record 44 of Set 10 | hovd
# Processing Record 45 of Set 10 | champua
# Processing Record 46 of Set 10 | vila
# Processing Record 47 of Set 10 | okhotsk
# Processing Record 48 of Set 10 | dongying
# Processing Record 49 of Set 10 | powell
# Processing Record 50 of Set 10 | alofi
# Processing Record 1 of Set 11 | boyolangu
# Processing Record 2 of Set 11 | vestmannaeyjar
# Processing Record 3 of Set 11 | suzaka
# Processing Record 4 of Set 11 | saint anthony
# Processing Record 5 of Set 11 | deputatskiy
# Processing Record 6 of Set 11 | ilovlya
# Processing Record 7 of Set 11 | mackay
# Processing Record 8 of Set 11 | piney green
# Processing Record 9 of Set 11 | obera
# Processing Record 10 of Set 11 | sidi bu zayd
# City not found. Skipping...
# Processing Record 11 of Set 11 | tura
# Processing Record 12 of Set 11 | sembakung
# Processing Record 13 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 14 of Set 11 | arlit
# Processing Record 15 of Set 11 | qaqortoq
# Processing Record 16 of Set 11 | tanout
# Processing Record 17 of Set 11 | puerto baquerizo moreno
# Processing Record 18 of Set 11 | bubaque
# Processing Record 19 of Set 11 | palmer
# Processing Record 20 of Set 11 | temerloh
# Processing Record 21 of Set 11 | naze
# Processing Record 22 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 11 | kolondieba
# Processing Record 24 of Set 11 | muscle shoals
# Processing Record 25 of Set 11 | taybad
# Processing Record 26 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 11 | jeremie
# Processing Record 28 of Set 11 | kralendijk
# Processing Record 29 of Set 11 | luderitz
# Processing Record 30 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 11 | las varas
# Processing Record 32 of Set 11 | bolu
# Processing Record 33 of Set 11 | akureyri
# Processing Record 34 of Set 11 | los llanos de aridane
# Processing Record 35 of Set 11 | aryanah
# Processing Record 36 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 11 | anadyr
# Processing Record 38 of Set 11 | ilebo
# Processing Record 39 of Set 11 | denpasar
# Processing Record 40 of Set 11 | calvinia
# Processing Record 41 of Set 11 | pavlodar
# Processing Record 42 of Set 11 | padang
# Processing Record 43 of Set 11 | jinxiang
# Processing Record 44 of Set 11 | luhyny
# Processing Record 45 of Set 11 | talcahuano
# Processing Record 46 of Set 11 | oum hadjer
# Processing Record 47 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 48 of Set 11 | caravelas
# Processing Record 49 of Set 11 | tres arroyos
# Processing Record 50 of Set 11 | korla
# Processing Record 1 of Set 12 | pampa
# Processing Record 2 of Set 12 | puerto colombia
# Processing Record 3 of Set 12 | mehamn
# Processing Record 4 of Set 12 | portland
# Processing Record 5 of Set 12 | nhulunbuy
# Processing Record 6 of Set 12 | aykhal
# Processing Record 7 of Set 12 | papetoai
# Processing Record 8 of Set 12 | ternate
# Processing Record 9 of Set 12 | sao filipe
# Processing Record 10 of Set 12 | sao jose da coroa grande
# Processing Record 11 of Set 12 | svetlyy
# Processing Record 12 of Set 12 | leopold
# Processing Record 13 of Set 12 | fier
# Processing Record 14 of Set 12 | jacareacanga
# Processing Record 15 of Set 12 | buin
# Processing Record 16 of Set 12 | kanker
# Processing Record 17 of Set 12 | vao
# Processing Record 18 of Set 12 | shenkursk
# Processing Record 19 of Set 12 | kazachinskoye
# Processing Record 20 of Set 12 | pokhara
# Processing Record 21 of Set 12 | kodinsk
# Processing Record 22 of Set 12 | yuzhno-kurilsk
# Processing Record 23 of Set 12 | saint george
# Processing Record 24 of Set 12 | el alto
# Processing Record 25 of Set 12 | maniitsoq
# Processing Record 26 of Set 12 | porto walter
# Processing Record 27 of Set 12 | waipawa
# Processing Record 28 of Set 12 | ballina
# Processing Record 29 of Set 12 | sergeyevka
# Processing Record 30 of Set 12 | dayong
# Processing Record 31 of Set 12 | corning
# Processing Record 32 of Set 12 | gurupi
# Processing Record 33 of Set 12 | sweetwater
# Processing Record 34 of Set 12 | lahij
# Processing Record 35 of Set 12 | iralaya
# Processing Record 36 of Set 12 | rafai
# Processing Record 37 of Set 12 | kutum
# Processing Record 38 of Set 12 | hualahuises
# Processing Record 39 of Set 12 | tezu
# Processing Record 40 of Set 12 | tambo
# Processing Record 41 of Set 12 | nuevitas
# Processing Record 42 of Set 12 | moerai
# Processing Record 43 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 12 | jamiltepec
# Processing Record 45 of Set 12 | ust-donetskiy
# Processing Record 46 of Set 12 | crixas
# Processing Record 47 of Set 12 | crotone
# Processing Record 48 of Set 12 | zunyi
# Processing Record 49 of Set 12 | camacha
# Processing Record 50 of Set 12 | chikmagalur
# Processing Record 1 of Set 13 | poli
# Processing Record 2 of Set 13 | faya
# Processing Record 3 of Set 13 | jinka
# Processing Record 4 of Set 13 | cabedelo
# Processing Record 5 of Set 13 | buala
# Processing Record 6 of Set 13 | sydney
# Processing Record 7 of Set 13 | hidrolandia
# Processing Record 8 of Set 13 | superior
# Processing Record 9 of Set 13 | slave lake
# Processing Record 10 of Set 13 | coahuayana
# Processing Record 11 of Set 13 | iranshahr
# Processing Record 12 of Set 13 | anito
# Processing Record 13 of Set 13 | flin flon
# Processing Record 14 of Set 13 | kudahuvadhoo
# Processing Record 15 of Set 13 | nushki
# Processing Record 16 of Set 13 | udachnyy
# Processing Record 17 of Set 13 | nago
# Processing Record 18 of Set 13 | kirakira
# Processing Record 19 of Set 13 | leh
# Processing Record 20 of Set 13 | yeppoon
# Processing Record 21 of Set 13 | havelock
# Processing Record 22 of Set 13 | pangody
# Processing Record 23 of Set 13 | mindelo
# Processing Record 24 of Set 13 | kuusamo
# Processing Record 25 of Set 13 | bosaso
# Processing Record 26 of Set 13 | novikovo
# Processing Record 27 of Set 13 | lahaina
# Processing Record 28 of Set 13 | huarmey
# Processing Record 29 of Set 13 | emerald
# Processing Record 30 of Set 13 | lloydminster
# Processing Record 31 of Set 13 | khovu-aksy
# Processing Record 32 of Set 13 | ketchikan
# Processing Record 33 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 13 | krasnoselkup
# Processing Record 35 of Set 13 | viedma
# Processing Record 36 of Set 13 | martil
# Processing Record 37 of Set 13 | hasaki
# Processing Record 38 of Set 13 | melo
# Processing Record 39 of Set 13 | pasighat
# Processing Record 40 of Set 13 | rhondda
# Processing Record 41 of Set 13 | sola
# Processing Record 42 of Set 13 | walla walla
# Processing Record 43 of Set 13 | umm lajj
# Processing Record 44 of Set 13 | yomou
# Processing Record 45 of Set 13 | haimen
# Processing Record 46 of Set 13 | bondoukou
# Processing Record 47 of Set 13 | novogornyy
# Processing Record 48 of Set 13 | penzance
# Processing Record 49 of Set 13 | presidencia roque saenz pena
# Processing Record 50 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 14 | tilichiki
# Processing Record 2 of Set 14 | borogontsy
# Processing Record 3 of Set 14 | saundatti yellamma
# City not found. Skipping...
# Processing Record 4 of Set 14 | ixtapa
# Processing Record 5 of Set 14 | bilma
# Processing Record 6 of Set 14 | high level
# Processing Record 7 of Set 14 | zhanaozen
# Processing Record 8 of Set 14 | dagana
# Processing Record 9 of Set 14 | baiao
# Processing Record 10 of Set 14 | fukue
# Processing Record 11 of Set 14 | puri
# Processing Record 12 of Set 14 | bandarbeyla
# Processing Record 13 of Set 14 | comodoro rivadavia
# Processing Record 14 of Set 14 | marzuq
# Processing Record 15 of Set 14 | pangnirtung
# Processing Record 16 of Set 14 | shache
# Processing Record 17 of Set 14 | wanning
# Processing Record 18 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 14 | sabla
# Processing Record 20 of Set 14 | falam
# Processing Record 21 of Set 14 | guane
# Processing Record 22 of Set 14 | goderich
# Processing Record 23 of Set 14 | sur
# Processing Record 24 of Set 14 | prata
# Processing Record 25 of Set 14 | shitanjing
# Processing Record 26 of Set 14 | le vauclin
# Processing Record 27 of Set 14 | chernyy yar
# Processing Record 28 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 14 | ayr
# Processing Record 30 of Set 14 | axim
# Processing Record 31 of Set 14 | chipata
# Processing Record 32 of Set 14 | hambantota
# Processing Record 33 of Set 14 | mahanoro
# Processing Record 34 of Set 14 | maumere
# Processing Record 35 of Set 14 | sulina
# Processing Record 36 of Set 14 | aspindza
# Processing Record 37 of Set 14 | sabaudia
# Processing Record 38 of Set 14 | teguldet
# Processing Record 39 of Set 14 | kaeo
# Processing Record 40 of Set 14 | egvekinot
# Processing Record 41 of Set 14 | caxito
# Processing Record 42 of Set 14 | kamen-rybolov
# Processing Record 43 of Set 14 | murdochville
# Processing Record 44 of Set 14 | mansa
# Processing Record 45 of Set 14 | stykkisholmur
# Processing Record 46 of Set 14 | nizhniy odes
# Processing Record 47 of Set 14 | gusinoye ozero
# Processing Record 48 of Set 14 | ust-nera
# Processing Record 49 of Set 14 | ahipara
# Processing Record 50 of Set 14 | saint-francois
# Processing Record 1 of Set 15 | emba
# Processing Record 2 of Set 15 | hirado
# Processing Record 3 of Set 15 | corn island
# Processing Record 4 of Set 15 | ingham
# Processing Record 5 of Set 15 | mansehra
# Processing Record 6 of Set 15 | moctezuma
# Processing Record 7 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 15 | waingapu
# Processing Record 9 of Set 15 | cacheu
# Processing Record 10 of Set 15 | tessalit
# Processing Record 11 of Set 15 | alcudia
# Processing Record 12 of Set 15 | beeville
# Processing Record 13 of Set 15 | pozo colorado
# Processing Record 14 of Set 15 | yafran
# Processing Record 15 of Set 15 | takaka
# Processing Record 16 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 17 of Set 15 | asau
# Processing Record 18 of Set 15 | iskateley
# Processing Record 19 of Set 15 | rincon
# Processing Record 20 of Set 15 | mashhad
# Processing Record 21 of Set 15 | soyo
# Processing Record 22 of Set 15 | arawa
# Processing Record 23 of Set 15 | san ramon
# Processing Record 24 of Set 15 | santa ana arriba
# Processing Record 25 of Set 15 | flinders
# Processing Record 26 of Set 15 | nantucket
# Processing Record 27 of Set 15 | korop
# Processing Record 28 of Set 15 | yar-sale
# Processing Record 29 of Set 15 | cam ranh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 673

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sao Joao Da Barra -21.6403  -41.0511     74.12        92          80
# 1             Yulara -25.2406  130.9889     79.05        22           0
# 2         Port Hardy  50.6996 -127.4199     41.18        93         100
# 3         Kaitangata -46.2817  169.8464     58.91        73          60
# 4            Shimoda  34.6667  138.9500     62.96        65          91
# 5            Ushuaia -54.8000  -68.3000     47.86        76           0
# 6            Sal Rei  16.1833  -22.9167     74.97        78          83
# 7             Albany  42.6001  -73.9662     36.57        72          42
# 8       Kruisfontein -34.0033   24.7314     56.30        72           0
# 9            Salalah  17.0151   54.0924     78.78        49           8
#
#    Wind Speed Country Current Description
# 0       17.43      BR       broken clouds
# 1        6.40      AU           clear sky
# 2        3.44      CA     overcast clouds
# 3       13.31      NZ       broken clouds
# 4       14.27      JP     overcast clouds
# 5        5.75      AR           clear sky
# 6       16.78      CV       broken clouds
# 7        1.01      US    scattered clouds
# 8        3.96      ZA           clear sky
# 9        2.62      OM           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Sao Joao Da Barra      BR -21.6403  -41.0511     74.12        92
# 1               Yulara      AU -25.2406  130.9889     79.05        22
# 2           Port Hardy      CA  50.6996 -127.4199     41.18        93
# 3           Kaitangata      NZ -46.2817  169.8464     58.91        73
# 4              Shimoda      JP  34.6667  138.9500     62.96        65
# ..                 ...     ...      ...       ...       ...       ...
# 668           Flinders      AU -34.5833  150.8552     79.18        49
# 669          Nantucket      US  41.2835  -70.0995     45.14        66
# 670              Korop      UA  51.5664   32.9586     34.88        93
# 671           Yar-Sale      RU  66.8333   70.8333      0.54        89
# 672           Cam Ranh      VN  11.9214  109.1591     87.76        70
#
#      Cloudiness  Wind Speed Current Description
# 0            80       17.43       broken clouds
# 1             0        6.40           clear sky
# 2           100        3.44     overcast clouds
# 3            60       13.31       broken clouds
# 4            91       14.27     overcast clouds
# ..          ...         ...                 ...
# 668          13       14.00          few clouds
# 669           4       29.86           clear sky
# 670          26        6.91    scattered clouds
# 671         100        9.42     overcast clouds
# 672          20       14.97          few clouds
#
# [673 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
